# %% [markdown]
# - https://data.winnipeg.ca/Recreation/Pool-Facility-Usage/j4s8-s9ap

# %%
#!pip install sodapy

# %%
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.winnipeg.ca", None)
results = client.get("t2d2-j4v9", limit=2000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df = pd.DataFrame.from_records(results)

# %%
df.columns
# Out:
# Index(['activity_category', 'activity_name', 'activity_number',
#        'activity_status', 'activity_type', 'attendance', 'center',
#        'customer_type', 'end_date', 'end_time', 'event_type', 'item_name',
#        'item_type', 'schedule_type', 'secondary_category', 'start_date',
#        'start_time'],
#       dtype='object')

# %%
df.head().T
# Out:
#                                            0  \
# activity_category                        NaN
# activity_name                            NaN
# activity_number                          NaN
# activity_status                          NaN
# activity_type                            NaN
# attendance                                30
# center                           Pan Am Pool
# customer_type               Authorized Agent
# end_date             2016-01-19T00:00:00.000
# end_time                             8:00 PM
# event_type          Aquatics - Contract User
# item_name              PAP - Middle - Lane 6
# item_type                      Pool - Indoor
# schedule_type           External Reservation
# secondary_category                       NaN
# start_date           2016-01-19T00:00:00.000
# start_time                           5:00 PM
#
#                                                    1  \
# activity_category                                NaN
# activity_name                                    NaN
# activity_number                                  NaN
# activity_status                                  NaN
# activity_type                                    NaN
# attendance                                        15
# center              Cindy Klassen Recreation Complex
# customer_type                       Authorized Agent
# end_date                     2016-01-30T00:00:00.000
# end_time                                     8:30 AM
# event_type                  Aquatics - Contract User
# item_name                     CKRC - Middle - Lane 7
# item_type                              Pool - Indoor
# schedule_type                   External Reservation
# secondary_category                               NaN
# start_date                   2016-01-30T00:00:00.000
# start_time                                   7:30 AM
#
#                                            2                                3  \
# activity_category                        NaN     Preschool - Birth to 5 years
# activity_name                            NaN  Kinder Ballet Level I 3-5 years
# activity_number                          NaN                             6259
# activity_status                          NaN                           Closed
# activity_type                            NaN                         Activity
# attendance                                30                               11
# center                           Pan Am Pool                      Pan Am Pool
# customer_type               Authorized Agent                              NaN
# end_date             2016-01-22T00:00:00.000          2016-02-20T00:00:00.000
# end_time                             7:30 AM                          9:45 AM
# event_type          Aquatics - Contract User                              NaN
# item_name             PAP - Middle - Lane 10       PAP - Kiddie Pool - Area 1
# item_type                      Pool - Indoor                    Pool - Indoor
# schedule_type           External Reservation                Standard Activity
# secondary_category                       NaN                 Movement/Fitness
# start_date           2016-01-22T00:00:00.000          2016-02-20T00:00:00.000
# start_time                           5:45 AM                          9:00 AM
#
#                                                   4
# activity_category                               NaN
# activity_name                                   NaN
# activity_number                                 NaN
# activity_status                                 NaN
# activity_type                                   NaN
# attendance                                        6
# center                                  Pan Am Pool
# customer_type                        General Public
# end_date                    2016-03-05T00:00:00.000
# end_time                                   11:30 AM
# event_type                 Aquatics - Contract User
# item_name           PAP - Training - North - Lane 1
# item_type                             Pool - Indoor
# schedule_type                  External Reservation
# secondary_category                              NaN
# start_date                  2016-03-05T00:00:00.000
# start_time                                 10:00 AM

# %%
client = Socrata("data.winnipeg.ca", None)
bugs = client.get("du7c-8488", limit=2000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
bugsdf = pd.DataFrame(bugs)
bugsdf.T
idvars = ['count_date', 'trap_days']

# %%
idvars = ['count_date', 'trap_days']
location_only = [x for x in bugsdf.columns if "average" not in x]
location_only = [x for x in location_only if x not in idvars]
len(location_only)
# Out:
# 37

# %%
# !ls
# Out:
# Datasets.ipynb	environment.yml

# %% [markdown]
# hello world

# %%
bugcleaned = pd.melt(bugsdf[location_only + idvars], id_vars = idvars, var_name = 'location', value_name = 'bugcount')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
parkbikedata = "9t9k-ya8b"
parkbikedf = client.get("9t9k-ya8b", limit=2000)

# %%
pd.DataFrame(parkbikedf).T
# Out:
#                                                           0     \
# asset_class                         STAND-ALONE PLAY COMPONENT
# asset_id                                                 46292
# asset_size                                                 N/A
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                   1137
# park_name                                       Frontenac Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.08174796...
#
#                                                           1     \
# asset_class                                            SEATING
# asset_id                                                 47525
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                    266
# park_name                                   Muriel Street Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.29729904...
#
#                                                           2     \
# asset_class                                            SEATING
# asset_id                                                 24478
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                   1179
# park_name                        Aberdeen Adventure Playground
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.12915711...
#
#                                                           3     \
# asset_class                                            SEATING
# asset_id                                                 22744
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                   1040
# park_name                                       Wightman Green
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.22794918...
#
#                                                           4     \
# asset_class                                            SEATING
# asset_id                                                 23769
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                     52
# park_name                           Rotary Prairie Nature Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.03366551...
#
#                                                           5     \
# asset_class                                            SEATING
# asset_id                                                 24506
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                    918
# park_name                                         Cordova Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.18933524...
#
#                                                           6     \
# asset_class                                          SWING SET
# asset_id                                                 44743
# asset_size                                               1 BAY
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                     55
# park_name                                          Scouts Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.00751582...
#
#                                                           7     \
# asset_class                         STAND-ALONE PLAY COMPONENT
# asset_id                                                 45304
# asset_size                                                 N/A
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                    410
# park_name                                         Parr Tot Lot
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.14154370...
#
#                                                           8     \
# asset_class                                     PLAY STRUCTURE
# asset_id                                                 46922
# asset_size                                               SMALL
# asset_type                                              2 TO 5
# geom_type                                                POINT
# park_id                                                   1137
# park_name                                       Frontenac Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.08170560...
#
#                                                           9     \
# asset_class                                            SEATING
# asset_id                                                 62218
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                     59
# park_name             Central Corydon C.C - River Heights Site
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.18075583...
#
#                                    ...                          \
# asset_class                        ...
# asset_id                           ...
# asset_size                         ...
# asset_type                         ...
# geom_type                          ...
# park_id                            ...
# park_name                          ...
# prim_field                         ...
# the_geom                           ...
#
#                                                           1990  \
# asset_class                                            SEATING
# asset_id                                                 35198
# asset_size                                                 N/A
# asset_type                                       PLAYERS BENCH
# geom_type                                                POINT
# park_id                                                   1070
# park_name                                      Kirkbridge Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.16548156...
#
#                                                           1991  \
# asset_class                                            SEATING
# asset_id                                                 24586
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                   1070
# park_name                                      Kirkbridge Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.16275159...
#
#                                                           1992  \
# asset_class                                            SEATING
# asset_id                                                 23821
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                    142
# park_name                              Valour C.C-Clifton Site
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.18967885...
#
#                                                           1993  \
# asset_class                         STAND-ALONE PLAY COMPONENT
# asset_id                                                 46209
# asset_size                                                 N/A
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                    237
# park_name                                  George Minaker Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.27178997...
#
#                                                           1994  \
# asset_class                         STAND-ALONE PLAY COMPONENT
# asset_id                                                 45287
# asset_size                                                 N/A
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                    173
# park_name                                         Pinkham Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.15868988...
#
#                                                           1995  \
# asset_class                                          SWING SET
# asset_id                                                 62281
# asset_size                                               1 BAY
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                    146
# park_name                        Valour C.C - Isaac Brock Site
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.18664174...
#
#                                                           1996  \
# asset_class                         STAND-ALONE PLAY COMPONENT
# asset_id                                                 45419
# asset_size                                                 N/A
# asset_type                                                 N/A
# geom_type                                                POINT
# park_id                                                   1129
# park_name                                     Evesham Key Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.26272864...
#
#                                                           1997  \
# asset_class                                            SEATING
# asset_id                                                 23978
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                    609
# park_name                                      Paulicelli Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.02866826...
#
#                                                           1998  \
# asset_class                                                BBQ
# asset_id                                                 38673
# asset_size                                                 N/A
# asset_type                                                 PIT
# geom_type                                                POINT
# park_id                                                   1313
# park_name                                         Kilcona Park
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.03826030...
#
#                                                           1999
# asset_class                                            SEATING
# asset_id                                                 22264
# asset_size                                                 N/A
# asset_type                                               BENCH
# geom_type                                                POINT
# park_id                                                    747
# park_name                                    Parc Joseph Royal
# prim_field                                                 N/A
# the_geom     {'type': 'Point', 'coordinates': [-97.12547259...
#
# [9 rows x 2000 columns]

# %%
client = Socrata("data.winnipeg.ca", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
bikeurl = "https://data.winnipeg.ca/resource/9t9k-ya8b.json"

# %%
client = Socrata("data.winnipeg.ca", None)
bikes = client.get("9t9k-ya8b", limit=2000)
bikes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0f1811847b39> in <module>()
# ----> 1 client = Socrata("data.winnipeg.ca", None)
#       2 bikes = client.get("9t9k-ya8b", limit=2000)
#       3 bikes
#
# NameError: name 'Socrata' is not defined

# %%
bikes_df = pd.DataFrame(bikes)
bikes_df.head()
# Out:
#                   asset_class asset_id asset_size asset_type geom_type  \
# 0  STAND-ALONE PLAY COMPONENT    46292        N/A        N/A     POINT
# 1                     SEATING    47525        N/A      BENCH     POINT
# 2                     SEATING    24478        N/A      BENCH     POINT
# 3                     SEATING    22744        N/A      BENCH     POINT
# 4                     SEATING    23769        N/A      BENCH     POINT
#
#   park_id                      park_name prim_field  \
# 0    1137                 Frontenac Park        N/A
# 1     266             Muriel Street Park        N/A
# 2    1179  Aberdeen Adventure Playground        N/A
# 3    1040                 Wightman Green        N/A
# 4      52     Rotary Prairie Nature Park        N/A
#
#                                             the_geom
# 0  {'type': 'Point', 'coordinates': [-97.08174796...
# 1  {'type': 'Point', 'coordinates': [-97.29729904...
# 2  {'type': 'Point', 'coordinates': [-97.12915711...
# 3  {'type': 'Point', 'coordinates': [-97.22794918...
# 4  {'type': 'Point', 'coordinates': [-97.03366551...

# %%
testcoord = bikes_df.the_geom[0]
testcoord
# Out:
# {'coordinates': [-97.081747962942, 49.864921789653], 'type': 'Point'}

# %%
import ipyleaflet

# %%
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Out:
# Enabling notebook extension jupyter-leaflet/extension...
#       - Validating: OK

# %%
from ipyleaflet import Map

# %%
Map(center = testcoord['coordinates'])
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[-97.081747962942, 49.864921789653], layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size']),), options=['attribution_control', 'basemap', 'bounce_at_zoom_limits', 'box_zoom', 'center', 'close_popup_on_click', 'double_click_zoom', 'dragging', 'inertia', 'inertia_deceleration', 'inertia_max_speed', 'keyboard', 'keyboard_pan_offset', 'keyboard_zoom_offset', 'max_zoom', 'min_zoom', 'scroll_wheel_zoom', 'tap', 'tap_tolerance', 'touch_zoom', 'world_copy_jump', 'zoom', 'zoom_animation_threshold', 'zoom_control', 'zoom_start'])

# %%
# for x in bugcleaned.location.unique():
#     print(x)

# %% [markdown]
# https://docs.google.com/document/d/1xWBXAFSwtUGgZ3hQmzXE7ODnufQEWkji26vnsqfZzZ0/
#
# http://winnipeg.ca/publicworks/insectcontrol/mosquitoes/nuisanceschedule.stm

# %%
client = Socrata("data.winnipeg.ca", None)
mapdata = "tug6-p73s"
mapdata = client.get("tug6-p73s", limit=2000)
mapdata
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-32-cc0b301327e8> in <module>()
#       1 client = Socrata("data.winnipeg.ca", None)
#       2 mapdata = "tug6-p73s"
# ----> 3 mapdata = client.get("tug6-p73s", limit=2000)
#       4 mapdata
#
# ~/anaconda3/envs/winnipeg/lib/python3.6/site-packages/sodapy/__init__.py in get(self, dataset_identifier, content_type, **kwargs)
#     250
#     251         response = self._perform_request("get", resource, headers=headers,
# --> 252                                          params=params)
#     253         return response
#     254
#
# ~/anaconda3/envs/winnipeg/lib/python3.6/site-packages/sodapy/__init__.py in _perform_request(self, request_type, resource, **kwargs)
#     365         # handle errors
#     366         if response.status_code not in (200, 202):
# --> 367             _raise_for_status(response)
#     368
#     369         # when responses have no content body (ie. delete, set_permission),
#
# ~/anaconda3/envs/winnipeg/lib/python3.6/site-packages/sodapy/__init__.py in _raise_for_status(response)
#     419         if more_info and more_info.lower() != response.reason.lower():
#     420             http_error_msg += ".\n\t{0}".format(more_info)
# --> 421         raise requests.exceptions.HTTPError(http_error_msg, response=response)
#     422
#     423
#
# HTTPError: 404 Client Error: Not Found.
# 	Dataset '_tug6-p73s' was not found

# %% [markdown]
# North_east_1:  49.951867, -97.059306
# North_east_2: 49.933941, -97.096341
# North_east_3: 49.924809, -97.056330
# North_east_4: 49.906175, -97.094797
# North_east_5: 49.892358, -97.022426
# North_east_6: 49.918257, -97.043848
# North_east_7: 49.904900, -96.981602
# North_west_1: 49.890104, -97.308464
# North_west_2: 49.882624, -97.238131
# North_west_3: 49.888943, -97.193254
# North_west_4: 49.920877, -97.202540
# North_west_5: 49.931627, -97.170450
# North_west_6: 49.975104, -97.147863
# North_west_7: 49.948876, -97.126311
# Rural_aa: 49.981128, -97.244987
# Rural_bb: 49.999793, -97.194880
# Rural_cc: 49.991068, -97.089770
# Rural_dd: 49.990523, -97.013920
# Rural_ee: 49.852485, -96.986202
# Rural_ff: 49.800355, -97.073122
# Rural_gg: 49.782835, -97.339871
# Rural_hh: 49.854707, -97.338403
# Rural_ii: 49.890188, -97.341707
# South_east_1: 49.5242.6, 97.07156
# South_east_2: 49.856801, -97.109705
# south_east_3:49.859405, -97.066774
# South_east_4: 49.824369, -97.133797
# South_east_5: 49.829048, -97.098352
# South_east_6: 49.827414, -97.060787
# South_east_7: 49.806356, -97.100467
# South_west_1: 49.832983, -97.332547
# South_west_2: 49.852445, -97.275173
# South_west_3: 49.868974, -97.243095
# South_west_4: 49.868834, -97.184476
# South_west_5: 49.818122, -97.165982
# South_west_6: 49.805538, -97.138229
# South_west_7: 49.827168, -97.170704

# %%
import geopandas

# %%
from geopandas import GeoDataFrame

# %%
from shapely.geometry import Point

# %%
mypoint = testcoord['coordinates']

# %%
GeoDataFrame()
# Out:
# Empty GeoDataFrame
# Columns: []
# Index: []

# %%
from shapely.geometry import Point

# %%
geotypes = [x['type'] for x in bikes_df.the_geom]

# %%
set(geotypes)
# Out:
# {'Point'}

# %%
Point()

# %%
newgeom = [Point(x['coordinates']) for x in bikes_df.the_geom]
bikes_df['newgeom'] = newgeom

# %%
gdf = bikes_df
gdf = gdf.set_geometry('newgeom')

# %%
gdf.head()
# Out:
#                   asset_class asset_id asset_size asset_type geom_type  \
# 0  STAND-ALONE PLAY COMPONENT    46292        N/A        N/A     POINT
# 1                     SEATING    47525        N/A      BENCH     POINT
# 2                     SEATING    24478        N/A      BENCH     POINT
# 3                     SEATING    22744        N/A      BENCH     POINT
# 4                     SEATING    23769        N/A      BENCH     POINT
#
#   park_id                      park_name prim_field  \
# 0    1137                 Frontenac Park        N/A
# 1     266             Muriel Street Park        N/A
# 2    1179  Aberdeen Adventure Playground        N/A
# 3    1040                 Wightman Green        N/A
# 4      52     Rotary Prairie Nature Park        N/A
#
#                                             the_geom  \
# 0  {'type': 'Point', 'coordinates': [-97.08174796...
# 1  {'type': 'Point', 'coordinates': [-97.29729904...
# 2  {'type': 'Point', 'coordinates': [-97.12915711...
# 3  {'type': 'Point', 'coordinates': [-97.22794918...
# 4  {'type': 'Point', 'coordinates': [-97.03366551...
#
#                                       newgeom
# 0    POINT (-97.081747962942 49.864921789653)
# 1    POINT (-97.297299049073 49.885573317262)
# 2  POINT (-97.12915711750099 49.914999354395)
# 3    POINT (-97.227949182553 49.884866541461)
# 4    POINT (-97.033665511373 49.898900466161)

# %%
gdf.plot()

# %%
gdf.set_geometry('newgeom')
# Out:
#                      asset_class asset_id asset_size     asset_type geom_type  \
# 0     STAND-ALONE PLAY COMPONENT    46292        N/A            N/A     POINT
# 1                        SEATING    47525        N/A          BENCH     POINT
# 2                        SEATING    24478        N/A          BENCH     POINT
# 3                        SEATING    22744        N/A          BENCH     POINT
# 4                        SEATING    23769        N/A          BENCH     POINT
# 5                        SEATING    24506        N/A          BENCH     POINT
# 6                      SWING SET    44743      1 BAY            N/A     POINT
# 7     STAND-ALONE PLAY COMPONENT    45304        N/A            N/A     POINT
# 8                 PLAY STRUCTURE    46922      SMALL         2 TO 5     POINT
# 9                        SEATING    62218        N/A          BENCH     POINT
# 10                  BICYCLE RACK    35899        N/A       STANDARD     POINT
# 11                PLAY STRUCTURE    46967      SMALL         2 TO 5     POINT
# 12                       SEATING    63043        N/A          BENCH     POINT
# 13    STAND-ALONE PLAY COMPONENT    46326        N/A            N/A     POINT
# 14                       SEATING    35140        N/A  PLAYERS BENCH     POINT
# 15    STAND-ALONE PLAY COMPONENT    46556        N/A            N/A     POINT
# 16                     SWING SET    44464      3 BAY            N/A     POINT
# 17                       SEATING    35031        N/A  PLAYERS BENCH     POINT
# 18                       SEATING    73816        N/A  PLAYERS BENCH     POINT
# 19                       SEATING    25024        N/A          BENCH     POINT
# 20                       SEATING    35218        N/A  PLAYERS BENCH     POINT
# 21                       SEATING    71927        N/A          BENCH     POINT
# 22                       SEATING    24488        N/A          BENCH     POINT
# 23    STAND-ALONE PLAY COMPONENT    52167        N/A            N/A     POINT
# 24                       SEATING    51263        N/A          BENCH     POINT
# 25                       SEATING    23809        N/A          BENCH     POINT
# 26                       SEATING    24784        N/A          BENCH     POINT
# 27    STAND-ALONE PLAY COMPONENT    45714        N/A            N/A     POINT
# 28                       SEATING    22678        N/A          BENCH     POINT
# 29                       SEATING    22492        N/A          BENCH     POINT
# ...                          ...      ...        ...            ...       ...
# 1970  STAND-ALONE PLAY COMPONENT    52137        N/A            N/A     POINT
# 1971  STAND-ALONE PLAY COMPONENT    45793        N/A            N/A     POINT
# 1972                     SEATING    24580        N/A          BENCH     POINT
# 1973                   SWING SET    44696      2 BAY            N/A     POINT
# 1974  STAND-ALONE PLAY COMPONENT    46380        N/A            N/A     POINT
# 1975                     SEATING    74206        N/A  PLAYERS BENCH     POINT
# 1976                         BBQ    38613        N/A            PIT     POINT
# 1977                   SWING SET    44366      2 BAY            N/A     POINT
# 1978              PLAY STRUCTURE    46641      SMALL         2 TO 5     POINT
# 1979                   SWING SET    44613      1 BAY            N/A     POINT
# 1980  STAND-ALONE PLAY COMPONENT    45858        N/A            N/A     POINT
# 1981                     SEATING    71867        N/A          BENCH     POINT
# 1982                     SEATING    22597        N/A          BENCH     POINT
# 1983                BICYCLE RACK    48335        N/A       STANDARD     POINT
# 1984                     SEATING    23374        N/A          BENCH     POINT
# 1985  STAND-ALONE PLAY COMPONENT    50016        N/A            N/A     POINT
# 1986  STAND-ALONE PLAY COMPONENT    73870        N/A            N/A     POINT
# 1983  POINT (-97.22231082388301 49.888280848855)
# 1984    POINT (-97.131441159668 49.820223080608)
# 1985    POINT (-97.143687783229 49.842096926429)
# 1986    POINT (-97.100592601521 49.858670779367)
# 1987    POINT (-97.148206381395 49.792683926907)
# 1988    POINT (-97.178410000181 49.930629916578)
# 1989  POINT (-97.30006939230501 49.880372217243)
# 1990    POINT (-97.165481561006 49.788582243845)
# 1991     POINT (-97.162751594056 49.79055494726)
# 1992  POINT (-97.18967885489501 49.901590527334)
# 1993    POINT (-97.271789978442 49.880462589261)
# 1994    POINT (-97.158689884315 49.907875968377)
# 1995    POINT (-97.186641745673 49.888307937728)
# 1996  POINT (-97.26272864982499 49.846292058902)
# 1997     POINT (-97.028668262571 49.88910590984)
# 1998    POINT (-97.038260305899 49.935581789272)
# 1999     POINT (-97.12547259589 49.891569112122)
#
# [2000 rows x 10 columns]

# %%
bikes_df
# Out:
#                      asset_class asset_id asset_size     asset_type geom_type  \
# 0     STAND-ALONE PLAY COMPONENT    46292        N/A            N/A     POINT
# 1                        SEATING    47525        N/A          BENCH     POINT
# 2                        SEATING    24478        N/A          BENCH     POINT
# 3                        SEATING    22744        N/A          BENCH     POINT
# 4                        SEATING    23769        N/A          BENCH     POINT
# 5                        SEATING    24506        N/A          BENCH     POINT
# 6                      SWING SET    44743      1 BAY            N/A     POINT
# 7     STAND-ALONE PLAY COMPONENT    45304        N/A            N/A     POINT
# 8                 PLAY STRUCTURE    46922      SMALL         2 TO 5     POINT
# 9                        SEATING    62218        N/A          BENCH     POINT
# 10                  BICYCLE RACK    35899        N/A       STANDARD     POINT
# 11                PLAY STRUCTURE    46967      SMALL         2 TO 5     POINT
# 12                       SEATING    63043        N/A          BENCH     POINT
# 13    STAND-ALONE PLAY COMPONENT    46326        N/A            N/A     POINT
# 14                       SEATING    35140        N/A  PLAYERS BENCH     POINT
# 15    STAND-ALONE PLAY COMPONENT    46556        N/A            N/A     POINT
# 16                     SWING SET    44464      3 BAY            N/A     POINT
# 17                       SEATING    35031        N/A  PLAYERS BENCH     POINT
# 18                       SEATING    73816        N/A  PLAYERS BENCH     POINT
# 19                       SEATING    25024        N/A          BENCH     POINT
# 20                       SEATING    35218        N/A  PLAYERS BENCH     POINT
# 21                       SEATING    71927        N/A          BENCH     POINT
# 22                       SEATING    24488        N/A          BENCH     POINT
# 23    STAND-ALONE PLAY COMPONENT    52167        N/A            N/A     POINT
# 24                       SEATING    51263        N/A          BENCH     POINT
# 25                       SEATING    23809        N/A          BENCH     POINT
# 26                       SEATING    24784        N/A          BENCH     POINT
# 27    STAND-ALONE PLAY COMPONENT    45714        N/A            N/A     POINT
# 28                       SEATING    22678        N/A          BENCH     POINT
# 29                       SEATING    22492        N/A          BENCH     POINT
# ...                          ...      ...        ...            ...       ...
# 1970  STAND-ALONE PLAY COMPONENT    52137        N/A            N/A     POINT
# 1971  STAND-ALONE PLAY COMPONENT    45793        N/A            N/A     POINT
# 1972                     SEATING    24580        N/A          BENCH     POINT
# 1973                   SWING SET    44696      2 BAY            N/A     POINT
# 1974  STAND-ALONE PLAY COMPONENT    46380        N/A            N/A     POINT
# 29      POINT (-97.083053872511 49.857177377911)
# ...                                          ...
# 1970    POINT (-97.090425279428 49.906119926596)
# 1971  POINT (-97.15352061033499 49.871460978259)
# 1972    POINT (-97.154623660018 49.768360804983)
# 1973    POINT (-97.079608599276 49.903927029609)
# 1974    POINT (-97.138660696253 49.862728860864)
# 1975      POINT (-97.0782470755 49.845011227708)
# 1976    POINT (-97.134609855382 49.833884250477)
# 1977    POINT (-97.115874158389 49.883417445343)
# 1978    POINT (-97.160897134774 49.901544143328)
# 1979     POINT (-97.063156724688 49.84637731159)
# 1980    POINT (-96.969089715987 49.902424281781)
# 1981     POINT (-97.20783275161 49.797111188538)
# 1982  POINT (-97.04972482301601 49.938745544448)
# 1983  POINT (-97.22231082388301 49.888280848855)
# 1984    POINT (-97.131441159668 49.820223080608)
# 1985    POINT (-97.143687783229 49.842096926429)
# 1986    POINT (-97.100592601521 49.858670779367)
# 1987    POINT (-97.148206381395 49.792683926907)
# 1988    POINT (-97.178410000181 49.930629916578)
# 1989  POINT (-97.30006939230501 49.880372217243)
# 1990    POINT (-97.165481561006 49.788582243845)
# 1991     POINT (-97.162751594056 49.79055494726)
# 1992  POINT (-97.18967885489501 49.901590527334)
# 1993    POINT (-97.271789978442 49.880462589261)
# 1994    POINT (-97.158689884315 49.907875968377)
# 1995    POINT (-97.186641745673 49.888307937728)
# 1996  POINT (-97.26272864982499 49.846292058902)
# 1997     POINT (-97.028668262571 49.88910590984)
# 1998    POINT (-97.038260305899 49.935581789272)
# 1999     POINT (-97.12547259589 49.891569112122)
#
# [2000 rows x 10 columns]

# %%
bikes_df
# Out:
#                      asset_class asset_id asset_size     asset_type geom_type  \
# 0     STAND-ALONE PLAY COMPONENT    46292        N/A            N/A     POINT
# 1                        SEATING    47525        N/A          BENCH     POINT
# 2                        SEATING    24478        N/A          BENCH     POINT
# 3                        SEATING    22744        N/A          BENCH     POINT
# 4                        SEATING    23769        N/A          BENCH     POINT
# 5                        SEATING    24506        N/A          BENCH     POINT
# 6                      SWING SET    44743      1 BAY            N/A     POINT
# 7     STAND-ALONE PLAY COMPONENT    45304        N/A            N/A     POINT
# 8                 PLAY STRUCTURE    46922      SMALL         2 TO 5     POINT
# 9                        SEATING    62218        N/A          BENCH     POINT
# 10                  BICYCLE RACK    35899        N/A       STANDARD     POINT
# 11                PLAY STRUCTURE    46967      SMALL         2 TO 5     POINT
# 12                       SEATING    63043        N/A          BENCH     POINT
# 13    STAND-ALONE PLAY COMPONENT    46326        N/A            N/A     POINT
# 14                       SEATING    35140        N/A  PLAYERS BENCH     POINT
# 15    STAND-ALONE PLAY COMPONENT    46556        N/A            N/A     POINT
# 16                     SWING SET    44464      3 BAY            N/A     POINT
# 17                       SEATING    35031        N/A  PLAYERS BENCH     POINT
# 18                       SEATING    73816        N/A  PLAYERS BENCH     POINT
# 19                       SEATING    25024        N/A          BENCH     POINT
# 20                       SEATING    35218        N/A  PLAYERS BENCH     POINT
# 21                       SEATING    71927        N/A          BENCH     POINT
# 22                       SEATING    24488        N/A          BENCH     POINT
# 23    STAND-ALONE PLAY COMPONENT    52167        N/A            N/A     POINT
# 24                       SEATING    51263        N/A          BENCH     POINT
# 25                       SEATING    23809        N/A          BENCH     POINT
# 26                       SEATING    24784        N/A          BENCH     POINT
# 27    STAND-ALONE PLAY COMPONENT    45714        N/A            N/A     POINT
# 28                       SEATING    22678        N/A          BENCH     POINT
# 29                       SEATING    22492        N/A          BENCH     POINT
# ...                          ...      ...        ...            ...       ...
# 1970  STAND-ALONE PLAY COMPONENT    52137        N/A            N/A     POINT
# 1971  STAND-ALONE PLAY COMPONENT    45793        N/A            N/A     POINT
# 1972                     SEATING    24580        N/A          BENCH     POINT
# 1973                   SWING SET    44696      2 BAY            N/A     POINT
# 1974  STAND-ALONE PLAY COMPONENT    46380        N/A            N/A     POINT
# 1975                     SEATING    74206        N/A  PLAYERS BENCH     POINT
# 1976                         BBQ    38613        N/A            PIT     POINT
# 1977                   SWING SET    44366      2 BAY            N/A     POINT
# 1978              PLAY STRUCTURE    46641      SMALL         2 TO 5     POINT
# 1979                   SWING SET    44613      1 BAY            N/A     POINT
# 1980  STAND-ALONE PLAY COMPONENT    45858        N/A            N/A     POINT
# 1981                     SEATING    71867        N/A          BENCH     POINT
# 1982                     SEATING    22597        N/A          BENCH     POINT
# 1983                BICYCLE RACK    48335        N/A       STANDARD     POINT
# 1984                     SEATING    23374        N/A          BENCH     POINT
# 1985  STAND-ALONE PLAY COMPONENT    50016        N/A            N/A     POINT
# 1986  STAND-ALONE PLAY COMPONENT    73870        N/A            N/A     POINT
# 1987              PLAY STRUCTURE    47041     MEDIUM        5 TO 12     POINT
# 1988              PLAY STRUCTURE    47019      SMALL        5 TO 12     POINT
# 1989  STAND-ALONE PLAY COMPONENT    79530        N/A            N/A     POINT
# 1990                     SEATING    35198        N/A  PLAYERS BENCH     POINT
# 1991                     SEATING    24586        N/A          BENCH     POINT
# 1992                     SEATING    23821        N/A          BENCH     POINT
# 1993  STAND-ALONE PLAY COMPONENT    46209        N/A            N/A     POINT
# 1994  STAND-ALONE PLAY COMPONENT    45287        N/A            N/A     POINT
# 1995                   SWING SET    62281      1 BAY            N/A     POINT
# 1996  STAND-ALONE PLAY COMPONENT    45419        N/A            N/A     POINT
# 1997                     SEATING    23978        N/A          BENCH     POINT
# 1998                         BBQ    38673        N/A            PIT     POINT
# 1999                     SEATING    22264        N/A          BENCH     POINT
#
#      park_id                                          park_name prim_field  \
# 0       1137                                     Frontenac Park        N/A
# 1        266                                 Muriel Street Park        N/A
# 2       1179                      Aberdeen Adventure Playground        N/A
# 3       1040                                     Wightman Green        N/A
# 4         52                         Rotary Prairie Nature Park        N/A
# 5        918                                       Cordova Park        N/A
# 6         55                                        Scouts Park        N/A
# 7        410                                       Parr Tot Lot        N/A
# 8       1137                                     Frontenac Park        N/A
# 9         59           Central Corydon C.C - River Heights Site        N/A
# 10       651            Central Corydon C.C - Crescentwood Site        N/A
# 11       152                                      Minto Tot Lot        N/A
# 12      1313                                       Kilcona Park        N/A
# 13       649                                  Hunterspoint Park        N/A
# 14      1220                     St. James Memorial Sports Park        N/A
# 19    {'type': 'Point', 'coordinates': [-97.13036889...
# 20    {'type': 'Point', 'coordinates': [-97.27353603...
# 21    {'type': 'Point', 'coordinates': [-97.20345109...
# 22    {'type': 'Point', 'coordinates': [-96.96393326...
# 23    {'type': 'Point', 'coordinates': [-97.08479081...
# 24    {'type': 'Point', 'coordinates': [-97.08350205...
# 25    {'type': 'Point', 'coordinates': [-97.19859718...
# 26    {'type': 'Point', 'coordinates': [-97.14259205...
# 27    {'type': 'Point', 'coordinates': [-97.13213963...
# 28    {'type': 'Point', 'coordinates': [-97.13159900...
# 29    {'type': 'Point', 'coordinates': [-97.08305387...
# ...                                                 ...
# 1970  {'type': 'Point', 'coordinates': [-97.09042527...
# 1971  {'type': 'Point', 'coordinates': [-97.15352061...
# 1972  {'type': 'Point', 'coordinates': [-97.15462366...
# 1973  {'type': 'Point', 'coordinates': [-97.07960859...
# 1974  {'type': 'Point', 'coordinates': [-97.13866069...
# 1975  {'type': 'Point', 'coordinates': [-97.07824707...
# 1976  {'type': 'Point', 'coordinates': [-97.13460985...
# 1977  {'type': 'Point', 'coordinates': [-97.11587415...
# 1978  {'type': 'Point', 'coordinates': [-97.16089713...
# 1979  {'type': 'Point', 'coordinates': [-97.06315672...
# 1980  {'type': 'Point', 'coordinates': [-96.96908971...
# 1981  {'type': 'Point', 'coordinates': [-97.20783275...
# 1982  {'type': 'Point', 'coordinates': [-97.04972482...
# 1983  {'type': 'Point', 'coordinates': [-97.22231082...
# 1984  {'type': 'Point', 'coordinates': [-97.13144115...
# 1985  {'type': 'Point', 'coordinates': [-97.14368778...
# 1986  {'type': 'Point', 'coordinates': [-97.10059260...
# 1987  {'type': 'Point', 'coordinates': [-97.14820638...
# 1988  {'type': 'Point', 'coordinates': [-97.17841000...
# 1989  {'type': 'Point', 'coordinates': [-97.30006939...
# 1990  {'type': 'Point', 'coordinates': [-97.16548156...
# 1991  {'type': 'Point', 'coordinates': [-97.16275159...
# 1992  {'type': 'Point', 'coordinates': [-97.18967885...
# 1993  {'type': 'Point', 'coordinates': [-97.27178997...
# 1994  {'type': 'Point', 'coordinates': [-97.15868988...
# 1995  {'type': 'Point', 'coordinates': [-97.18664174...
# 1996  {'type': 'Point', 'coordinates': [-97.26272864...
# 1997  {'type': 'Point', 'coordinates': [-97.02866826...
# 1998  {'type': 'Point', 'coordinates': [-97.03826030...
# 1999  {'type': 'Point', 'coordinates': [-97.12547259...
#
# [2000 rows x 9 columns]

# %%
import geopandas as gpd

# %%
gdf = gpd.GeoDataFrame(bikes)

# %%
gdf.set_geometry('the_geom')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ffd1b926b369> in <module>()
# ----> 1 gdf.set_geometry('the_geom')
#
# ~/anaconda3/envs/winnipeg/lib/python3.6/site-packages/geopandas/geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     146         # Check that we are using a listlike of geometries
#     147         if not all(isinstance(item, BaseGeometry) or not item for item in level):
# --> 148             raise TypeError("Input geometry column must contain valid geometry objects.")
#     149         frame[geo_column_name] = level
#     150         frame._geometry_column_name = geo_column_name
#
# TypeError: Input geometry column must contain valid geometry objects.
